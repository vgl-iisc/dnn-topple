# %%
import pandas as pd

table = pd.read_csv("resnet_distances_e140.csv")

# %%
table["k"] = list(table.columns)

# %%
#  move column k to the front
table = table[["k"] + [col for col in table.columns if col != "k"]]

# %%
print(table.to_latex(index=False, float_format="%.4f", column_format="lcc", label="tab:resnet_distances_e140"))
# Out:
# \begin{table}
# \label{tab:resnet_distances_e140}
# \begin{tabular}{lcc}
# \toprule
# k & 15 & 20 & 25 & 30 & 35 & 40 & 45 & 60 & 80 \\
# \midrule
# 15 & 0.0000 & 0.0026 & 0.0059 & 0.0087 & 0.0087 & 0.0087 & 0.0087 & 0.0087 & 0.0087 \\
# 20 & 0.0026 & 0.0000 & 0.0059 & 0.0087 & 0.0087 & 0.0087 & 0.0087 & 0.0087 & 0.0087 \\
# 25 & 0.0059 & 0.0059 & 0.0000 & 0.0077 & 0.0077 & 0.0077 & 0.0077 & 0.0077 & 0.0077 \\
# 30 & 0.0087 & 0.0087 & 0.0077 & 0.0000 & 0.0015 & 0.0015 & 0.0015 & 0.0037 & 0.0037 \\
# 35 & 0.0087 & 0.0087 & 0.0077 & 0.0015 & 0.0000 & 0.0006 & 0.0012 & 0.0029 & 0.0029 \\
# 40 & 0.0087 & 0.0087 & 0.0077 & 0.0015 & 0.0006 & 0.0000 & 0.0008 & 0.0029 & 0.0029 \\
# 45 & 0.0087 & 0.0087 & 0.0077 & 0.0015 & 0.0012 & 0.0008 & 0.0000 & 0.0029 & 0.0029 \\
# 60 & 0.0087 & 0.0087 & 0.0077 & 0.0037 & 0.0029 & 0.0029 & 0.0029 & 0.0000 & 0.0002 \\
# 80 & 0.0087 & 0.0087 & 0.0077 & 0.0037 & 0.0029 & 0.0029 & 0.0029 & 0.0002 & 0.0000 \\
# \bottomrule
# \end{tabular}
# \end{table}
