# %%
# %load_ext autoreload
# %autoreload 2

from balance_metrics import plot_epoch_metrics_vs_accuracies
data = '../experiment_data/imbalance_metrics_cross_epoch_split_1e-2.csv'

# %%
plot_epoch_metrics_vs_accuracies(data, '../charts/imbalance_1e-2/')

# %%
plot_epoch_metrics_vs_accuracies(data, '../charts/imbalance_1e-2_99.0/', ignore_percentile=99.0)
# Out:
# Ignoring above 99.0 percentile value 4747.2 for metric colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring above 99.0 percentile value 1146.1199999999994 for metric sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring above 99.0 percentile value 1534.1399999999992 for metric total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring above 99.0 percentile value 4.885 for metric average_colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring above 99.0 percentile value 3.6394047619047636 for metric average_sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring above 99.0 percentile value 2.6916666666666673 for metric average_total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# ...

# %%
plot_epoch_metrics_vs_accuracies(data, '../charts/imbalance_1e-2_95.0/', ignore_percentile=95.0)
# Out:
# Ignoring above 95.0 percentile value 2807.9999999999977 for metric colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring above 95.0 percentile value 562.5999999999989 for metric sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring above 95.0 percentile value 950.6999999999996 for metric total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring above 95.0 percentile value 4.674999999999999 for metric average_colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring above 95.0 percentile value 2.911309523809523 for metric average_sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring above 95.0 percentile value 1.7916666666666665 for metric average_total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# ...

# %%
plot_epoch_metrics_vs_accuracies(data, '../charts/imbalance_1e-2_3std/', ignore_std=3.0)
# Out:
# Ignoring values outside 3.0 std dev (0.4461423913856506, 2.7745735296550893) for metric average_branching_factor on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring values outside 3.0 std dev (-3614.9699213148806, 4625.469921314881) for metric colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring values outside 3.0 std dev (-869.4469617399092, 1116.1136284065758) for metric sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring values outside 3.0 std dev (-1194.745362292702, 1580.0310765784163) for metric total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring values outside 3.0 std dev (-4.235941196861052, 6.149402735322591) for metric average_colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# ...

# %%
plot_epoch_metrics_vs_accuracies(data, '../charts/imbalance_1e-2_2std/', ignore_std=2.0)
# Out:
# Ignoring values outside 2.0 std dev (0.8342142477638904, 2.3865016732768494) for metric average_branching_factor on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring values outside 2.0 std dev (-2241.563280876587, 3252.063280876587) for metric colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring values outside 2.0 std dev (-538.520196715495, 785.1868633821617) for metric sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring values outside 2.0 std dev (-732.2826224808491, 1117.5683367665633) for metric total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring values outside 2.0 std dev (-2.505050541497112, 4.41851207995865) for metric average_colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# ...

# %%
plot_epoch_metrics_vs_accuracies(data, '../charts/imbalance_1e-2_1std/', ignore_std=1.0)
# Out:
# Ignoring values outside 1.0 std dev (1.2222861041421302, 1.9984298168986097) for metric average_branching_factor on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring values outside 1.0 std dev (-891.0641166447707, 2238.397449978104) for metric colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring values outside 1.0 std dev (-213.173371416747, 548.8097350531107) for metric sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring values outside 1.0 std dev (-264.9348806012899, 804.3348806012898) for metric total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# Ignoring values outside 1.0 std dev (-0.5758347324689159, 3.3397236213578045) for metric average_colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.01))
# ...
