# %%
# %load_ext autoreload
# %autoreload 2

from balance_metrics import plot_epoch_metrics_vs_accuracies
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plot_epoch_metrics_vs_accuracies('../experiment_data/imbalance_metrics_cross_epoch_split.csv', '../charts/imbalance/')

# %%
plot_epoch_metrics_vs_accuracies('../experiment_data/imbalance_metrics_cross_epoch_split_double.csv', '../charts/imbalance_double/')

# %%
plot_epoch_metrics_vs_accuracies('../experiment_data/imbalance_metrics_cross_epoch_split_1e-3.csv', '../charts/imbalance_1e-3/')

# %%
plot_epoch_metrics_vs_accuracies('../experiment_data/imbalance_metrics_cross_epoch_split_1e-3.csv', '../charts/imbalance_1e-3_99.9/', 99.9)
# Out:
# Ignoring above 99.9 percentile value 8658.184000000008 for metric colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.001))
# Ignoring above 99.9 percentile value 2216.1980000000012 for metric sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.001))
# Ignoring above 99.9 percentile value 3874.5880000000034 for metric total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.001))
# Ignoring above 99.9 percentile value 4871.080000000008 for metric colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'trainUval', np.float64(0.001))
# Ignoring above 99.9 percentile value 344.53200000000004 for metric sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'trainUval', np.float64(0.001))
# Ignoring above 99.9 percentile value 2481.628 for metric total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'trainUval', np.float64(0.001))
# ...

# %%
plot_epoch_metrics_vs_accuracies('../experiment_data/imbalance_metrics_cross_epoch_split_1e-3.csv', '../charts/imbalance_1e-3_99.0/', 99.0)
# Out:
# Ignoring above 99.0 percentile value 7966.839999999999 for metric colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.001))
# Ignoring above 99.0 percentile value 1983.9799999999989 for metric sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.001))
# Ignoring above 99.0 percentile value 3672.8799999999987 for metric total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.001))
# Ignoring above 99.0 percentile value 4223.799999999999 for metric colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'trainUval', np.float64(0.001))
# Ignoring above 99.0 percentile value 340.32 for metric sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'trainUval', np.float64(0.001))
# Ignoring above 99.0 percentile value 2451.2799999999997 for metric total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'trainUval', np.float64(0.001))
# ...

# %%
plot_epoch_metrics_vs_accuracies('../experiment_data/imbalance_metrics_cross_epoch_split_1e-3.csv', '../charts/imbalance_1e-3_95.0/', 95.0)
# Out:
# Ignoring above 95.0 percentile value 4894.199999999997 for metric colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.001))
# Ignoring above 95.0 percentile value 951.899999999998 for metric sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.001))
# Ignoring above 95.0 percentile value 2776.3999999999996 for metric total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.001))
# Ignoring above 95.0 percentile value 1346.9999999999968 for metric colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'trainUval', np.float64(0.001))
# Ignoring above 95.0 percentile value 321.59999999999997 for metric sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'trainUval', np.float64(0.001))
# Ignoring above 95.0 percentile value 2316.3999999999996 for metric total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'trainUval', np.float64(0.001))
# ...

# %%
plot_epoch_metrics_vs_accuracies('../experiment_data/imbalance_metrics_cross_epoch_split_1e-3.csv', '../charts/imbalance_1e-3_90.0/', 90.0)
# Out:
# Ignoring above 90.0 percentile value 1898.800000000001 for metric colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.001))
# Ignoring above 90.0 percentile value 267.1000000000001 for metric sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.001))
# Ignoring above 90.0 percentile value 235.10000000000002 for metric total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.001))
# Ignoring above 90.0 percentile value 431.2 for metric colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'trainUval', np.float64(0.001))
# Ignoring above 90.0 percentile value 255.40000000000015 for metric sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'trainUval', np.float64(0.001))
# Ignoring above 90.0 percentile value 211.0 for metric total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'trainUval', np.float64(0.001))
# ...

# %%
plot_epoch_metrics_vs_accuracies('../experiment_data/imbalance_metrics_cross_epoch_split_1e-3.csv', '../charts/imbalance_1e-3_92.0/', 92.0)
# Out:
# Ignoring above 92.0 percentile value 2984.240000000002 for metric colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.001))
# Ignoring above 92.0 percentile value 288.68000000000006 for metric sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.001))
# Ignoring above 92.0 percentile value 369.6800000000011 for metric total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'train', np.float64(0.001))
# Ignoring above 92.0 percentile value 440.16 for metric colless_index on ('cifar', 'densenet', np.int64(20), 'a1', 'trainUval', np.float64(0.001))
# Ignoring above 92.0 percentile value 295.56 for metric sackin_index on ('cifar', 'densenet', np.int64(20), 'a1', 'trainUval', np.float64(0.001))
# Ignoring above 92.0 percentile value 568.0800000000019 for metric total_cophenetic_index on ('cifar', 'densenet', np.int64(20), 'a1', 'trainUval', np.float64(0.001))
# ...
