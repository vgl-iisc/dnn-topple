# %%
# %load_ext autoreload
# %autoreload 2

import pyct as ct
from make_layout import make_layouts
from make_icicle import make_icicle
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path_templ = lambda e: f"C:/home/sumatra_llvis_data/strees_cross_epoch_better/vgg_mnist/trainUval/ctree_a1_e{e}_20"

# %%
for i in [10, 11, 20, 150]:
    make_layouts(path_templ(i))

# %%
fig = make_icicle(path_templ(10))
fig.show()
# Out:
# Loaded 70000 parts from C:/home/sumatra_llvis_data/strees_cross_epoch_better/vgg_mnist/trainUval/ctree_a1_e10_20.part.raw

# %%
fig = make_icicle(path_templ(11))
fig.show()
# Out:
# Loaded 70000 parts from C:/home/sumatra_llvis_data/strees_cross_epoch_better/vgg_mnist/trainUval/ctree_a1_e11_20.part.raw

# %%
fig = make_icicle(path_templ(15))
fig.show()
# Out:
# Loaded 70000 parts from C:/home/sumatra_llvis_data/strees_cross_epoch_better/vgg_mnist/trainUval/ctree_a1_e15_20.part.raw

# %%
fig = make_icicle(path_templ(18))
fig.show()
# Out:
# Loaded 70000 parts from C:/home/sumatra_llvis_data/strees_cross_epoch_better/vgg_mnist/trainUval/ctree_a1_e18_20.part.raw

# %%
fig = make_icicle(path_templ(20))
fig.show()
# Out:
# Loaded 70000 parts from C:/home/sumatra_llvis_data/strees_cross_epoch_better/vgg_mnist/trainUval/ctree_a1_e20_20.part.raw
