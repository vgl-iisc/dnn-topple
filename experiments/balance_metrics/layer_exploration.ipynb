# %%
# %load_ext autoreload
# %autoreload 2

import yaml
from balance_metrics import plot_epoch_metrics_vs_accuracies, get_data, plot_layer_metrics, plot_exp_regressions, plot_linear_regressions

epoch_path = "../../experiment_data/balance_metrics/cross_epoch.csv"
layer_path = "../../experiment_data/balance_metrics/cross_layer.csv"
layer_path_better = "../../experiment_data/balance_metrics/cross_layer_better.csv"
block_path = "../../experiment_data/balance_metrics/intra_block.csv"

epoch_data = get_data(epoch_path)
layer_data = get_data(layer_path)
block_data = get_data(block_path)
layer_data_better = get_data(layer_path_better)

layer_data_better["model"] = layer_data_better["model"].apply(lambda x: f"{x}_better")

with open('../layer_orders_cross_layer.yml', 'r') as f:
    layer_order = yaml.safe_load(f)

with open('../layer_orders_intra_block.yml', 'r') as f:
    block_order = yaml.safe_load(f)
    
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

import plotly.io as pio
pio.renderers.default = "vscode"

color_seq = px.colors.qualitative.Dark24
color_seq_train = px.colors.qualitative.Pastel
color_seq_val = px.colors.qualitative.Set1

# %%
full_data = pd.concat([layer_data, layer_data_better], ignore_index=True)

# %%
resnet = full_data[(full_data["model"].str.contains("resnet")) & (full_data["split"] == "trainUval")].copy()

resnet["layer_idx"] = resnet["layer"].apply(lambda x: layer_order['resnet'].index(x))
resnet.sort_values("layer_idx", inplace=True)

fig = px.line(resnet, x="layer", y="colless_index", color="dataset", symbol="model", color_discrete_sequence=px.colors.qualitative.Plotly, title="ResNet Colless")
fig.update_xaxes(tickangle=80)
fig.update_yaxes(type="log")

# %%
resnet["layer_idx"] = resnet["layer"].apply(lambda x: layer_order['resnet'].index(x))
resnet.sort_values("layer_idx", inplace=True)

fig = px.line(resnet, x="layer", y="average_sackin_index", color="dataset", symbol="model", color_discrete_sequence=px.colors.qualitative.Plotly, title="ResNet Sackin")
fig.update_xaxes(tickangle=80)
# fig.update_yaxes(type="log")

# %%
vgg = full_data[(full_data["model"].str.contains("vgg")) & (full_data["split"] == "trainUval")].copy()

vgg["layer_idx"] = vgg["layer"].apply(lambda x: layer_order['vgg'].index(x))
vgg.sort_values("layer_idx", inplace=True)

fig = px.line(vgg, x="layer", y="colless_index", color="dataset", symbol="model", color_discrete_sequence=px.colors.qualitative.Plotly, title="vgg Colless")
fig.update_xaxes(tickangle=80)
fig.update_yaxes(type="log")

# %%
vgg = full_data[(full_data["model"].str.contains("vgg")) & (full_data["split"] == "trainUval")].copy()

vgg["layer_idx"] = vgg["layer"].apply(lambda x: layer_order['vgg'].index(x))
vgg.sort_values("layer_idx", inplace=True)

fig = px.line(vgg, x="layer", y="sackin_index", color="dataset", symbol="model", color_discrete_sequence=px.colors.qualitative.Plotly, title="vgg Sackin")
fig.update_xaxes(tickangle=80)
# fig.update_yaxes(type="log")

# %%
densenet = full_data[(full_data["model"].str.contains("densenet")) & (full_data["split"] == "trainUval")].copy()

densenet["layer_idx"] = densenet["layer"].apply(lambda x: layer_order['densenet'].index(x))
densenet.sort_values("layer_idx", inplace=True)

fig = px.line(densenet, x="layer", y="colless_index", color="dataset", symbol="model", color_discrete_sequence=px.colors.qualitative.Plotly, title="densenet Colless")
fig.update_xaxes(tickangle=80)
# fig.update_yaxes(type="log")

# %%
densenet = full_data[(full_data["model"].str.contains("densenet")) & (full_data["split"] == "trainUval")].copy()

densenet["layer_idx"] = densenet["layer"].apply(lambda x: layer_order['densenet'].index(x))
densenet.sort_values("layer_idx", inplace=True)

fig = px.line(densenet, x="layer", y="sackin_index", color="dataset", symbol="model", color_discrete_sequence=px.colors.qualitative.Plotly, title="densenet Sackin")
fig.update_xaxes(tickangle=80)
# fig.update_yaxes(type="log")

# %%
wres = full_data[(full_data["model"].str.contains("wres")) & (full_data["split"] == "trainUval")].copy()

wres["layer_idx"] = wres["layer"].apply(lambda x: layer_order['wres'].index(x))
wres.sort_values("layer_idx", inplace=True)

fig = px.line(wres, x="layer", y="colless_index", color="dataset", symbol="model", color_discrete_sequence=px.colors.qualitative.Plotly, title="wres Colless")
fig.update_xaxes(tickangle=80)
fig.update_yaxes(type="log")

# %%
wres = full_data[(full_data["model"].str.contains("wres")) & (full_data["split"] == "trainUval")].copy()

wres["layer_idx"] = wres["layer"].apply(lambda x: layer_order['wres'].index(x))
wres.sort_values("layer_idx", inplace=True)

fig = px.line(wres, x="layer", y="sackin_index", color="dataset", symbol="model", color_discrete_sequence=px.colors.qualitative.Plotly, title="wres Sackin")
fig.update_xaxes(tickangle=80)
fig.update_yaxes(type="log")
