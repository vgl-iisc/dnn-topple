# %%
# %load_ext autoreload
# %autoreload 2

from balance_metrics import compute_correlations, get_data

epoch_data = get_data("../../experiment_data/balance_metrics/cross_epoch_better_e6.csv")

# %%
IGNORE_STDS = [0.0]
suffix = lambda f: f"_std{f}" if f != 0.0 else ""

# %%
for f in IGNORE_STDS:
	compute_correlations(epoch_data, "../../experiment_data/balance_metrics/cross_epoch_better_corrs_e6" + suffix(f) + ".csv", ignore_std=f)
# Out:
# Correlation results saved to ../../experiment_data/balance_metrics/cross_epoch_better_corrs_e6.csv
