# %%
# %load_ext autoreload
# %autoreload 2

from balance_metrics import compute_correlations, get_data

epoch_data = get_data("../../experiment_data/balance_metrics/cross_epoch.csv")
layer_data = get_data("../../experiment_data/balance_metrics/cross_layer.csv")
block_data = get_data("../../experiment_data/balance_metrics/intra_block.csv")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
IGNORE_STDS = [0.0, 0.2, 0.5, 1.0, 2.0, 5.0]
suffix = lambda f: f"_std{f}" if f != 0.0 else ""

# %%
for f in IGNORE_STDS:
	compute_correlations(epoch_data, "../../experiment_data/balance_metrics/cross_epoch_corrs" + suffix(f) + ".csv", ignore_std=f)
# Out:
# Correlation results saved to ../../experiment_data/balance_metrics/cross_epoch_corrs.csv
# Ignoring values outside 0.2 std dev (2.0248928920871303, 2.0443381588166143) for metric average_branching_factor
# Ignoring values outside 0.2 std dev (132680.68797417567, 256489.45156070805) for metric colless_index
# Ignoring values outside 0.2 std dev (1342510.5474477871, 1658182.7157101077) for metric sackin_index
# Ignoring values outside 0.2 std dev (61105.572809000085, 62894.427190999915) for metric total_volume
# Ignoring values outside 0.2 std dev (nan, nan) for metric missing_colless_frac
# Ignoring values outside 0.2 std dev (2.0244892259317386, 2.043882635934698) for metric average_branching_factor
# Ignoring values outside 0.2 std dev (116687.15378052517, 295710.4462194748) for metric colless_index
# Ignoring values outside 0.2 std dev (1724979.7044380975, 2096358.6955619024) for metric sackin_index
# Ignoring values outside 0.2 std dev (nan, nan) for metric total_volume
# ...
