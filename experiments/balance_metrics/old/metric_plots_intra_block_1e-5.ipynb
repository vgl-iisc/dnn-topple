# %%
# %load_ext autoreload
# %autoreload 2

import yaml
from balance_metrics import plot_layer_metrics
data = '../experiment_data/imbalance_metrics_intra_block_split_1e-5.csv'

with open('./layer_orders_intra_block.yml', 'r') as f:
    order = yaml.safe_load(f)
    
print(order)
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# {'resnet': ['al1-b0-c1', 'al1-b0-bn1', 'al1-b0-relu', 'al1-b0-c2', 'al1-b0-bn2', 'al1-b1-c1', 'al1-b1-bn1', 'al1-b1-relu', 'al1-b1-c2', 'al1-b1-bn2', 'al4-b0-c1', 'al4-b0-bn1', 'al4-b0-relu', 'al4-b0-c2', 'al4-b0-bn2', 'al4-b0-downsample-conv', 'al4-b0-downsample-bn', 'al4-b1-c1', 'al4-b1-bn1', 'al4-b1-relu', 'al4-b1-c2', 'al4-b1-bn2', 'aavgpool', 'afc'], 'vgg': ['ablock1-conv1', 'ablock1-relu1', 'ablock1-conv2', 'ablock1-relu2', 'ablock1-pool', 'ablock5-conv1', 'ablock5-relu1', 'ablock5-conv2', 'ablock5-relu2', 'ablock5-conv3', 'ablock5-relu3', 'ablock5-pool', 'aavgpool', 'afc1', 'afc1-relu', 'afc1-dropout', 'afc2', 'afc2-relu', 'afc2-dropout', 'afc3']}

# %%
plot_layer_metrics(data, out_dir='../charts/layer_metrics_intra_block_split_1e-5/', ignore_percentile=0.0, ignore_std=0.0, layer_order=order)

# %%
plot_layer_metrics(data, out_dir='../charts/layer_metrics_intra_block_split_1e-5_8std/', ignore_percentile=0.0, ignore_std=8.0, layer_order=order)
# Out:
# Ignoring values outside 8.0 std dev (1.759261919511963, 2.271007078200456) for metric average_branching_factor
# Ignoring values outside 8.0 std dev (-32091.125660915826, 36384.45899424916) for metric colless_index
# Ignoring values outside 8.0 std dev (-16801.069963937527, 19321.73663060419) for metric sackin_index
# Ignoring values outside 8.0 std dev (-716166.0355226618, 799813.368855995) for metric total_cophenetic_index
# Ignoring values outside 8.0 std dev (-123.72159216574839, 147.9215488113572) for metric average_colless_index
# Ignoring values outside 8.0 std dev (-58.867740126273375, 75.06895799053471) for metric average_sackin_index
# Ignoring values outside 8.0 std dev (-2964.5641586570396, 3363.2642863272763) for metric average_total_cophenetic_index
# Ignoring values outside 8.0 std dev (1.7954497557861195, 2.2285264441687875) for metric average_branching_factor
# Ignoring values outside 8.0 std dev (-52137.48173538954, 58713.48173538954) for metric colless_index
# ...
