# %%
# %load_ext autoreload
# %autoreload 2

from balance_metrics import plot_linear_regressions, get_data, plot_exp_regressions

data = get_data("../experiment_data/imbalance_metrics_cross_epoch_split_1e-2.csv")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
plot_linear_regressions(data, "../charts/imbalance_1e-2_regs_3std", ignore_std=3.0)
# Out:
# Ignoring values outside 3.0 std dev (1.4314385302060522, 2.3327323789080108) for metric average_branching_factor
# Ignoring values outside 3.0 std dev (-26214.836215485087, 28280.4018991312) for metric colless_index
# Ignoring values outside 3.0 std dev (-3192.714546837515, 3702.336168459137) for metric sackin_index
# Ignoring values outside 3.0 std dev (-25545.959474008723, 29168.255364419685) for metric total_cophenetic_index
# Ignoring values outside 3.0 std dev (-6.191646451402887, 12.29062355566832) for metric average_colless_index
# Ignoring values outside 3.0 std dev (0.2114145937006784, 5.548240498431383) for metric average_sackin_index
# Ignoring values outside 3.0 std dev (-9.681212904304655, 24.67703708605048) for metric average_total_cophenetic_index
# Ignoring values outside 3.0 std dev (1.2520945085701611, 2.4609114892739354) for metric average_branching_factor
# Ignoring values outside 3.0 std dev (-35752.66663772503, 39125.756584814975) for metric colless_index
# ...

# %%
plot_linear_regressions(data, "../charts/imbalance_1e-2_regs_5std", ignore_std=5.0)
# Out:
# Ignoring values outside 5.0 std dev (1.1310072473053994, 2.6331636618086636) for metric average_branching_factor
# Ignoring values outside 5.0 std dev (-44379.915587023854, 46445.48127066997) for metric colless_index
# Ignoring values outside 5.0 std dev (-8347.162083936273, 9047.172836624446) for metric sackin_index
# Ignoring values outside 5.0 std dev (-85107.28023935478, 90828.3701576109) for metric total_cophenetic_index
# Ignoring values outside 5.0 std dev (-18.374495703685152, 25.269002839136274) for metric average_colless_index
# Ignoring values outside 5.0 std dev (-5.684769000575185, 12.006785425298423) for metric average_sackin_index
# Ignoring values outside 5.0 std dev (-122.92719343742624, 147.5896331486316) for metric average_total_cophenetic_index
# Ignoring values outside 5.0 std dev (0.8491555150022365, 2.86385048284186) for metric average_branching_factor
# Ignoring values outside 5.0 std dev (-59662.24751874119, 62914.86996772078) for metric colless_index
# ...

# %%
plot_linear_regressions(data, "../charts/imbalance_1e-2_regs")

# %%
plot_exp_regressions(data, "../charts/imbalance_1e-2_exp_regs_3std", ignore_std=3.0)
# Out:
# Ignoring values outside 3.0 std dev (1.4314385302060522, 2.3327323789080108) for metric average_branching_factor
# Ignoring values outside 3.0 std dev (-26214.836215485087, 28280.4018991312) for metric colless_index
# Ignoring values outside 3.0 std dev (-3192.714546837515, 3702.336168459137) for metric sackin_index
# Ignoring values outside 3.0 std dev (-25545.959474008723, 29168.255364419685) for metric total_cophenetic_index
# Ignoring values outside 3.0 std dev (-6.191646451402887, 12.29062355566832) for metric average_colless_index
# Ignoring values outside 3.0 std dev (0.2114145937006784, 5.548240498431383) for metric average_sackin_index
# Ignoring values outside 3.0 std dev (-9.681212904304655, 24.67703708605048) for metric average_total_cophenetic_index
# Ignoring values outside 3.0 std dev (1.2520945085701611, 2.4609114892739354) for metric average_branching_factor
# Ignoring values outside 3.0 std dev (-35752.66663772503, 39125.756584814975) for metric colless_index
# ...

# %%
plot_exp_regressions(data, "../charts/imbalance_1e-2_exp_regs_5std", ignore_std=5.0)
# Out:
# Ignoring values outside 5.0 std dev (1.1310072473053994, 2.6331636618086636) for metric average_branching_factor
# Ignoring values outside 5.0 std dev (-44379.915587023854, 46445.48127066997) for metric colless_index
# Ignoring values outside 5.0 std dev (-8347.162083936273, 9047.172836624446) for metric sackin_index
# Ignoring values outside 5.0 std dev (-85107.28023935478, 90828.3701576109) for metric total_cophenetic_index
# Ignoring values outside 5.0 std dev (-18.374495703685152, 25.269002839136274) for metric average_colless_index
# Ignoring values outside 5.0 std dev (-5.684769000575185, 12.006785425298423) for metric average_sackin_index
# Ignoring values outside 5.0 std dev (-122.92719343742624, 147.5896331486316) for metric average_total_cophenetic_index
# Ignoring values outside 5.0 std dev (0.8491555150022365, 2.86385048284186) for metric average_branching_factor
# Ignoring values outside 5.0 std dev (-59662.24751874119, 62914.86996772078) for metric colless_index
# ...

# %%
plot_exp_regressions(data, "../charts/imbalance_1e-2_exp_regs")
