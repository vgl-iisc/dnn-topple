# %%
# %load_ext autoreload
# %autoreload 2

import yaml
from balance_metrics import plot_epoch_metrics_vs_accuracies, get_data, plot_layer_metrics, plot_exp_regressions, plot_linear_regressions

epoch_path = "../../experiment_data/balance_metrics/cross_epoch.csv"
layer_path = "../../experiment_data/balance_metrics/cross_layer.csv"
block_path = "../../experiment_data/balance_metrics/intra_block.csv"

epoch_data = get_data(epoch_path)
layer_data = get_data(layer_path)
block_data = get_data(block_path)

with open('../layer_orders_cross_layer.yml', 'r') as f:
    layer_order = yaml.safe_load(f)

with open('../layer_orders_intra_block.yml', 'r') as f:
    block_order = yaml.safe_load(f)
    
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

import plotly.io as pio
pio.renderers.default = "vscode"

color_seq = px.colors.qualitative.Dark24
color_seq_train = px.colors.qualitative.Pastel
color_seq_val = px.colors.qualitative.Set1
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
resnet = block_data[(block_data['model']=='resnet') & (block_data['split']=='trainUval')].copy()

resnet["layer_idx"] = resnet["layer"].apply(lambda x: block_order['resnet'].index(x))
resnet.sort_values("layer_idx", inplace=True)

fig = px.line(resnet, x="layer", y="colless_index", color="dataset", color_discrete_sequence=px.colors.qualitative.Plotly, title="ResNet Colless")
fig.update_xaxes(tickangle=80)
fig.update_yaxes(type="log")

# %%
resnet = block_data[(block_data['model']=='resnet') & (block_data['split']=='trainUval')].copy()

resnet["layer_idx"] = resnet["layer"].apply(lambda x: block_order['resnet'].index(x))
resnet.sort_values("layer_idx", inplace=True)

fig = px.line(resnet, x="layer", y="sackin_index", color="dataset", color_discrete_sequence=px.colors.qualitative.Plotly, title="ResNet Sackin")
fig.update_xaxes(tickangle=80)
fig.update_yaxes(type="log")

# %%
vgg = block_data[(block_data['model']=='vgg') & (block_data['split']=='trainUval')].copy()

vgg["layer_idx"] = vgg["layer"].apply(lambda x: block_order['vgg'].index(x))
vgg.sort_values("layer_idx", inplace=True)

fig = px.line(vgg, x="layer", y="colless_index", color="dataset", color_discrete_sequence=px.colors.qualitative.Plotly, title="VGG Colless")
fig.update_xaxes(tickangle=80)
fig.update_yaxes(type="log")

# %%
vgg = block_data[(block_data['model']=='vgg') & (block_data['split']=='trainUval')].copy()

vgg["layer_idx"] = vgg["layer"].apply(lambda x: block_order['vgg'].index(x))
vgg.sort_values("layer_idx", inplace=True)

fig = px.line(vgg, x="layer", y="sackin_index", color="dataset", color_discrete_sequence=px.colors.qualitative.Plotly, title="VGG Sackin")
fig.update_xaxes(tickangle=80)
fig.update_yaxes(type="log")
