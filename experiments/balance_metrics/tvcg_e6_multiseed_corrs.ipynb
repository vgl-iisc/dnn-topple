# %%
# %load_ext autoreload
# %autoreload 2

import os
import yaml
from balance_metrics import get_data, compute_correlations

prefix = "../../experiment_data/balance_metrics/tvcg/"
data = ["entropy_s_1e6.csv", "gradimp_j_1e6.csv", "gradimp_s_1e6.csv", "loss_s_1e6.csv", "margin_j_1e6.csv", "l2_s_1e6.csv", "l2_j_1e6.csv"]

for d in data:
    data_path = os.path.join(prefix, d)
    data = get_data(data_path)
    data = data[data["layer"] == "a1"]  # Filter to only penultimate layer for correlations
    compute_correlations(data, data_path.replace(".csv", "_penultimate_corr.csv"))
# Out:
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/sklearn/utils/_param_validation.py:14: UserWarning: A NumPy version >=1.23.5 and <2.5.0 is required for this version of SciPy (detected version 2.5.1)
#   from scipy.sparse import csr_matrix, issparse
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# Correlation results saved to ../../experiment_data/balance_metrics/tvcg/entropy_s_1e6_penultimate_corr.csv
# Correlation results saved to ../../experiment_data/balance_metrics/tvcg/gradimp_j_1e6_penultimate_corr.csv
# Correlation results saved to ../../experiment_data/balance_metrics/tvcg/gradimp_s_1e6_penultimate_corr.csv
# Correlation results saved to ../../experiment_data/balance_metrics/tvcg/loss_s_1e6_penultimate_corr.csv
# Correlation results saved to ../../experiment_data/balance_metrics/tvcg/margin_j_1e6_penultimate_corr.csv
# Correlation results saved to ../../experiment_data/balance_metrics/tvcg/l2_s_1e6_penultimate_corr.csv
# Correlation results saved to ../../experiment_data/balance_metrics/tvcg/l2_j_1e6_penultimate_corr.csv
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3036: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[:, None]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/numpy/lib/_function_base_impl.py:3037: RuntimeWarning: invalid value encountered in divide
#   c /= stddev[None, :]
# /home/santripta/miniconda3/envs/llvis/lib/python3.13/site-packages/pandas/core/nanops.py:1632: ConstantInputWarning: An input array is constant; the correlation coefficient is not defined.
#   return spearmanr(a, b)[0]
