# %%
# %load_ext autoreload
# %autoreload 2

import sys

sys.path.append("scripts")

from plot_coverage_evolution import plot_coverage_evolution

# %%
file = "experiment_data/densenet-mnist-trainUval-const.csv"

# %%
plot_coverage_evolution(file, filter_classes=[0], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[1], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[2], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[3], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[4], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[5], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[6], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[7], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[8], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[9], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %% [markdown]
# ### Resnet

# %%
file = "experiment_data/resnet-mnist-trainUval-const.csv"

# %%
plot_coverage_evolution(file, filter_classes=[0], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[1], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[2], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[3], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[4], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[5], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[6], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[7], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[8], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, filter_classes=[9], show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)

# %%
plot_coverage_evolution(file, show=True)
# Out:
# (<Figure size 1200x700 with 1 Axes>,
#  <Axes: title={'center': 'Coverage Evolution Across Network Layers'}, xlabel='Layer (left = earlier in network)', ylabel='Coverage (%)'>)
