# %%
import pickle as pkl

with open("rn_times_6.pkl", "rb") as f:
	times_dict = pkl.load(f)

times_dict
# Out:
# {(124800, 512): [23.988834399962798, 23.880410199984908],
#  (145600, 512): [29.061512499989476, 28.34599049994722],
#  (20800, 512): [2.114108900015708, 2.0867118000169285],
#  (124800, 4096): [99.95885709999129, 100.35856710001826],
#  (145600, 4096): [91.69983080000384, 91.88992169999983],
#  (20800, 4096): [8.723398999951314, 8.82710739999311]}

# %%
import pickle as pkl

with open("rn_times_24.pkl", "rb") as f:
	times_dict = pkl.load(f)

times_dict
# Out:
# {(124800, 512): [48.3804730999982, 45.718395499978215],
#  (145600, 512): [59.41027180000674, 55.61382859997684],
#  (20800, 512): [5.248338700039312, 4.963906900025904],
#  (124800, 4096): [180.76805820001755, 180.39949630002957],
#  (145600, 4096): [201.26685790001648, 201.19419230002677],
#  (20800, 4096): [21.676950699998997, 22.526313800015487]}
