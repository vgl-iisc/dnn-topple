# %%
# %load_ext autoreload
# %autoreload 2

import sys

sys.path.append('../../training-inference')

from imagenet_loader import ImageNetDataset, make_imagenet_dataloaders
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
path = "C:/home/imagenet"

dataset = ImageNetDataset(path)

# %%
make_imagenet_dataloaders(path, batch_size=1)
# Out:
# (<torch.utils.data.dataloader.DataLoader at 0x29e6f34e900>,
#  <torch.utils.data.dataloader.DataLoader at 0x29e0cbb5950>)

# %%
with open("classes.txt", "w") as f:
    f.write(",".join([t[0] for t in dataset.imagenet.classes]))
