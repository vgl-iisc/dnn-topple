# %%
from cifar10_loader import make_cifar10_dataloaders, get_cifar10_transforms
from emnist_loader import make_emnist_dataloaders, get_emnist_transforms
from mnist_loader import make_mnist_dataloaders, get_mnist_transforms

# %%
train_tf, test_tf = get_cifar10_transforms()
train_loader, test_loader = make_cifar10_dataloaders("../../datasets/cifar/data", train_transform=train_tf, test_transform=test_tf)
# Out:
# c:\Users\Santripta\miniconda3\envs\llvis\Lib\site-packages\torchvision\datasets\cifar.py:83: VisibleDeprecationWarning: dtype(): align should be passed as Python or NumPy boolean but got `align=0`. Did you mean to pass a tuple to create a subarray type? (Deprecated NumPy 2.4)
#   entry = pickle.load(f, encoding="latin1")

# %%
import matplotlib.pyplot as plt
plt.imshow(train_loader.dataset[10]["image"].permute(1, 2, 0))
train_loader.dataset[3]
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-1.1911422..1.6304358].
# {'image': tensor([[[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000, -0.0684,  ...,  0.0269, -0.0049, -0.0208],
#           ...,
#           [ 0.0000,  0.0000,  0.3444,  ...,  1.2176,  1.1065,  1.0112],
#           [ 0.0000,  0.0000,  0.2650,  ...,  1.1383,  1.0589,  0.9636],
#           [ 0.0000,  0.0000,  0.1380,  ...,  1.0430,  1.0112,  0.9636]],
#
#          [[ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.0000,  ...,  0.0000,  0.0000,  0.0000],
#           [ 0.0000,  0.0000,  0.1456,  ...,  0.2261,  0.1939,  0.1778],
#           ...,
#           [ 0.0000,  0.0000, -0.5469,  ...,  0.3388,  0.1778,  0.1134],
# ...

# %%
train_tf, test_tf = get_mnist_transforms()
train_loader, test_loader = make_mnist_dataloaders("../../datasets/mnist/data", transform=train_tf)

# %%
train_loader.dataset[0]["image"].shape
# Out:
# torch.Size([3, 32, 32])

# %%
train_tf, test_tf = get_emnist_transforms()
train_loader, test_loader = make_emnist_dataloaders("../../datasets/emnist_letters/data", variant="letters", transform=train_tf)

# %%
train_loader.dataset[0]
# Out:
# {'image': tensor([[[-0.4242, -0.4242, -0.4242,  ..., -0.4242, -0.4242, -0.4242],
#           [-0.4242, -0.4242, -0.4242,  ..., -0.4242, -0.4242, -0.4242],
#           [-0.4242, -0.4242, -0.4242,  ..., -0.4242, -0.4242, -0.4242],
#           ...,
#           [-0.4242, -0.4242, -0.4242,  ..., -0.4242, -0.4242, -0.4242],
#           [-0.4242, -0.4242, -0.4242,  ..., -0.4242, -0.4242, -0.4242],
#           [-0.4242, -0.4242, -0.4242,  ..., -0.4242, -0.4242, -0.4242]],
#
#          [[-0.4242, -0.4242, -0.4242,  ..., -0.4242, -0.4242, -0.4242],
#           [-0.4242, -0.4242, -0.4242,  ..., -0.4242, -0.4242, -0.4242],
#           [-0.4242, -0.4242, -0.4242,  ..., -0.4242, -0.4242, -0.4242],
#           ...,
#           [-0.4242, -0.4242, -0.4242,  ..., -0.4242, -0.4242, -0.4242],
#           [-0.4242, -0.4242, -0.4242,  ..., -0.4242, -0.4242, -0.4242],
#           [-0.4242, -0.4242, -0.4242,  ..., -0.4242, -0.4242, -0.4242]],
#
# ...
