# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

import plotly.io as pio
pio.renderers.default = "vscode"
pio.templates.default = "ggplot2"

color_seq = px.colors.qualitative.Dark24
color_seq_train = px.colors.qualitative.Pastel
color_seq_val = px.colors.qualitative.Set1

metric_data = pd.read_csv("../../experiment_data/separability_metrics/geometric_separability_subset_corrs_final.csv")
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
metric_data.replace({"split": {"cifar_resnet": "CIFAR-10 ResNet", "cifar_densenet": "CIFAR-10 DenseNet", "full": "Full"}, "metric": {"centroid_mean_separation": "Mean Centroid Separation", "knn_accuracy_20": "KNN Accuracy", "silhouette_score": "Silhouette Score", "sackin_index_k20": "Sackin Index", "average_sackin_index_k20": "Avg Sackin", "centroid_mean_correlation": "Mean Centroid Correlation"}}, inplace=True)

# %%
metric_data
# Out:
#                        metric              split label     value
# 0    Mean Centroid Separation               Full   v_p  0.691840
# 1    Mean Centroid Separation  CIFAR-10 DenseNet   v_p -0.381725
# 2    Mean Centroid Separation    CIFAR-10 ResNet   v_p -0.135211
# 3   Mean Centroid Correlation               Full   v_p -0.697739
# 4   Mean Centroid Correlation  CIFAR-10 DenseNet   v_p -0.721897
# 5   Mean Centroid Correlation    CIFAR-10 ResNet   v_p -0.906086
# 6                KNN Accuracy               Full   v_p  0.932347
# 7                KNN Accuracy  CIFAR-10 DenseNet   v_p  0.935631
# 8                KNN Accuracy    CIFAR-10 ResNet   v_p  0.928516
# 9            Silhouette Score               Full   v_p  0.625673
# 10           Silhouette Score  CIFAR-10 DenseNet   v_p  0.657512
# 11           Silhouette Score    CIFAR-10 ResNet   v_p  0.598686
# 12               Sackin Index               Full   v_p -0.868760
# ...

# %%
fig = px.scatter(metric_data, x="metric", y="value", color="split", color_discrete_sequence=color_seq_val)
fig.update_yaxes(title="Correlation with Validation Accuracy", title_standoff=18, automargin=True)
fig.update_xaxes(title="", title_standoff=0, automargin=True)
fig.update_layout(margin=dict(l=0, r=0, t=0, b=0), width=300*2, height=260*2, font=dict(size=16), showlegend=False)
fig.write_image(f"metrics.png", scale=8)
