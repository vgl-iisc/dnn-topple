# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import yaml

epoch_better_path = "../../experiment_data/balance_metrics/cross_epoch_better_e6.csv"

epoch_data = pd.read_csv(epoch_better_path)

import numpy as np
import plotly.express as px
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import matplotlib.pyplot as plt

import plotly.io as pio
pio.renderers.default = "vscode"
pio.templates.default = "ggplot2"

color_seq = px.colors.qualitative.Dark24
color_seq_train = px.colors.qualitative.Pastel
color_seq_val = px.colors.qualitative.Set1
epoch_data.head()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#   dataset  split     model   k  epoch layer    thresh  thresh_mode  \
# 0   cifar  train  densenet  20      0    a1  0.000001     0.000001
# 1   cifar  train  densenet  20    125    a1  0.000001     0.000001
# 2   cifar  train  densenet  20    150    a1  0.000001     0.000001
# 3   cifar  train  densenet  20    176    a1  0.000001     0.000001
# 4   cifar  train  densenet  20    200    a1  0.000001     0.000001
#
#    node_count  average_branching_factor  ...  average_colless_index  \
# 0        2294                  2.099817  ...            5356.109658
# 1         629                  2.052288  ...             715.298611
# 2         768                  2.050802  ...             733.389831
# 3         285                  2.028571  ...             893.432836
# 4         360                  2.028249  ...            1021.429412
#
#    total_colless  missing_colless  missing_colless_frac  sackin_index  \
# 0            994               98              0.089744    52616904.0
# 1            288               18              0.058824     2628066.0
# 2            354               20              0.053476     1920430.0
# 3            134                6              0.042857     2773274.0
# 4            170                7              0.039548     2416259.0
#
#    average_sackin_index  leaf_count  total_volume  train_acc  val_acc
# 0          43774.462562        1202         50000    0.09992   0.0998
# 1           8136.427245         323         50000    0.99836   0.8659
# 2           4874.187817         394         50000    0.99990   0.8752
# 3          19126.027586         145         50000    0.97020   0.8464
# 4          13203.601093         183         50000    0.97902   0.8529
#
# [5 rows x 21 columns]

# %%
epoch_trainUval = epoch_data[(epoch_data["split"] == "trainUval") & (epoch_data["model"] == "resnet") & (epoch_data["dataset"] == "cifar")]
epoch_trainUval = epoch_trainUval.sort_values(by='epoch')

fig = make_subplots(specs=[[{"secondary_y": True}]], )

train_acc = px.line(epoch_trainUval, x='epoch', y='train_acc', color="dataset", width=15, color_discrete_sequence=color_seq_train)
val_acc = px.line(epoch_trainUval, x='epoch', y='val_acc', color="dataset", width=15, color_discrete_sequence=color_seq_val)
sackin = px.scatter(epoch_trainUval, x='epoch', y='sackin_index', color="dataset", color_discrete_sequence=color_seq)

best_epoch = epoch_trainUval[epoch_trainUval["val_acc"] == epoch_trainUval["val_acc"].max()]["epoch"].values[0]

fig.add_trace(sackin.data[0], secondary_y=False)
fig.add_trace(train_acc.data[0], secondary_y=True)
fig.add_trace(val_acc.data[0], secondary_y=True)

fig.update_annotations(font_size=16)
fig.update_layout(margin=dict(l=0, r=0, t=0, b=0), width=400*2, height=180*2, font=dict(size=14), showlegend=False)
fig.update_xaxes(title_text="Epoch", title_standoff=18, automargin=True, range=[0,200])
fig.update_yaxes(title_text="Sackin Index (log)", type="log", title_standoff=18, automargin=True, secondary_y=False)
fig.update_yaxes(title_text="Accuracy", title_standoff=18, automargin=True, secondary_y=True, nticks=10, range=[0, 1.05])
fig.write_image(f"resnet-cifar-epoch.png", scale=8)

# %%
epoch_trainUval = epoch_data[(epoch_data["split"] == "trainUval") & (epoch_data["model"] == "vgg") & (epoch_data["dataset"] == "mnist")]
epoch_trainUval = epoch_trainUval.sort_values(by='epoch')

fig = make_subplots(specs=[[{"secondary_y": True}]], )

train_acc = px.line(epoch_trainUval, x='epoch', y='train_acc', color="dataset", color_discrete_sequence=color_seq_train)
val_acc = px.line(epoch_trainUval, x='epoch', y='val_acc', color="dataset", color_discrete_sequence=color_seq_val)
sackin = px.scatter(epoch_trainUval, x='epoch', y='sackin_index', color="dataset", color_discrete_sequence=color_seq)

fig.add_trace(sackin.data[0], secondary_y=False)
fig.add_trace(train_acc.data[0], secondary_y=True)
fig.add_trace(val_acc.data[0], secondary_y=True)

fig.update_annotations(font_size=16)
fig.update_layout(margin=dict(l=0, r=0, t=0, b=0), width=400*2, height=180*2, font=dict(size=14), showlegend=False)
fig.update_xaxes(title_text="Epoch", title_standoff=18, automargin=True, range=[0,200])
fig.update_yaxes(title_text="Sackin Index (log)", type="log", title_standoff=18, automargin=True, secondary_y=False)
fig.update_yaxes(title_text="Accuracy", title_standoff=18, automargin=True, secondary_y=True, nticks=10, range=[0, 1.05])
fig.write_image(f"vgg-mnist-epoch.png", scale=8)

# %%
epoch_trainUval = epoch_data[(epoch_data["split"] == "trainUval") & (epoch_data["model"] == "resnet") & (epoch_data["dataset"] == "cifar")]
epoch_trainUval = epoch_trainUval.sort_values(by='epoch')

fig = make_subplots(specs=[[{"secondary_y": True}]], )

train_acc = px.line(epoch_trainUval, x='epoch', y='train_acc', color="dataset", color_discrete_sequence=color_seq_train, symbol="model")
val_acc = px.line(epoch_trainUval, x='epoch', y='val_acc', color="dataset", markers=False, color_discrete_sequence=color_seq_val)
sackin = px.scatter(epoch_trainUval, x='epoch', y='sackin_index', color="dataset", color_discrete_sequence=color_seq, symbol="model")

best_epoch = epoch_trainUval[epoch_trainUval["val_acc"] == epoch_trainUval["val_acc"].max()]["epoch"].values[0]

fig.add_trace(sackin.data[0], secondary_y=False)
# fig.add_trace(train_acc.data[0], secondary_y=True)
fig.add_trace(val_acc.data[0], secondary_y=True)

fig.update_xaxes(title_text="Epoch")
fig.update_yaxes(title_text="Sackin Index (log scale)", type="log", secondary_y=False)
fig.update_yaxes(title_text="Accuracy", secondary_y=True)
fig.update_annotations(font_size=16)
fig.update_layout(margin=dict(l=0, r=0, t=0, b=0), width=250*2, height=200*2, font=dict(size=14), showlegend=False)
# fig.show()
fig.write_image(f"interface-across-epoch.png", scale=8)
