# %%
import pickle
import pandas as pd

knn_times = {}
with open("knn_times.pkl", "rb") as f:
    knn_times = pickle.load(f)

# %%
keys_with_multiple = [k for k, v in knn_times.items() if len(v) > 1]

# %%
data = []

for k in keys_with_multiple:
    n, d = k
    times = knn_times[k]
    mean = sum(times) / len(times)
    max_dev = max(abs(mean - x) for x in times)
    std_dev = sum(abs(mean - x) for x in times) / (len(times) + 1)
    
    data.append({"Data Points": n, "Dimension": d, "Mean Time (s)": mean, "Max Deviation (s)": max_dev, "Std. Deviation (s)": std_dev})

df = pd.DataFrame(data)
df
# Out:
#     Data Points  Dimension  Mean Time (s)  Max Deviation (s)  \
# 0         50000       1024      17.044676           2.113131
# 1         50000       4096      51.694072           0.595320
# 2         60000       1024      19.185684           2.343185
# 3         60000        512      13.561726           0.147304
# 4         60000       4096      77.315284           4.931104
# 5         60000       8192      98.931575           7.953036
# 6         60000       2048      27.999866           1.707123
# 7         60000      16384     191.439057          18.047902
# 8         10000       1024       2.473663           0.030579
# 9         10000        512       2.398657           0.120382
# 10        10000       4096       3.888811           0.187491
# 11        10000       8192       5.177944           0.210415
# 12        10000       2048       2.810567           0.084711
# 13        10000      16384       8.589189           0.600445
# 14        70000       1024      28.210142           1.398042
# 15        70000       4096     100.488591           1.645658
#
#     Std. Deviation (s)
# 0             1.408754
# 1             0.396880
# 2             1.543820
# 3             0.098202
# 4             1.972442
# 5             5.302024
# 6             1.138082
# 7            12.031934
# 8             0.017040
# 9             0.080254
# 10            0.074996
# 11            0.140276
# 12            0.056474
# 13            0.400297
# 14            0.932028
# 15            1.097105

# %%
df2 = df.drop(columns=["Max Deviation (s)"]).sort_values(by=["Data Points", "Dimension"])
df2 = df2[(df2["Data Points"] == 10000) | (df2["Data Points"] == 60000)]

# %%
print(df2.to_latex(index=False, ))
# Out:
# \begin{tabular}{rrrr}
# \toprule
# Data Points & Dimension & Mean Time (s) & Std. Deviation (s) \\
# \midrule
# 10000 & 512 & 2.398657 & 0.080254 \\
# 10000 & 1024 & 2.473663 & 0.017040 \\
# 10000 & 2048 & 2.810567 & 0.056474 \\
# 10000 & 4096 & 3.888811 & 0.074996 \\
# 10000 & 8192 & 5.177944 & 0.140276 \\
# 10000 & 16384 & 8.589189 & 0.400297 \\
# 60000 & 512 & 13.561726 & 0.098202 \\
# 60000 & 1024 & 19.185684 & 1.543820 \\
# 60000 & 2048 & 27.999866 & 1.138082 \\
# 60000 & 4096 & 77.315284 & 1.972442 \\
# 60000 & 8192 & 98.931575 & 5.302024 \\
# 60000 & 16384 & 191.439057 & 12.031934 \\
# \bottomrule
# \end{tabular}
